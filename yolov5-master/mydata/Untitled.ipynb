# %%
import os 
f=os.listdir("labels/val")

# %%
for i in f:
    os.rename("labels/val/"+i,"labels/val/val"+i)

# %%
f
# Out:
# ['fall001.jpg',
#  'fall002.jpg',
#  'fall003.jpg',
#  'fall004.jpg',
#  'fall005.jpg',
#  'fall006.jpg',
#  'fall007.jpg',
#  'fall008.jpg',
#  'fall009.jpg',
#  'fall010.jpg',
#  'fall011.jpg',
#  'fall012.jpg',
#  'fall013.jpg',
#  'fall014.jpg',
#  'fall015.jpg',
#  'fall016.jpg',
#  'fall017.jpg',
#  'fall018.jpg',
#  'fall019.jpg',
#  'fall020.jpg',
#  'fall021.jpg',
#  'fall022.jpg',
#  'fall023.jpg',
#  'fall024.jpg',
#  'fall025.jpg',
#  'fall026.jpg',
#  'fall027.jpg',
#  'fall028.jpg',
#  'fall029.jpg',
#  'fall030.jpg',
#  'fall031.jpg',
#  'fall032.jpg',
#  'fall033.jpg',
#  'fall034.jpg',
#  'fall035.jpg',
#  'fall036.jpg',
#  'fall037.jpg',
#  'fall038.jpg',
#  'fall039.jpg',
#  'fall040.jpg',
#  'fall041.jpg',
#  'fall042.jpg',
#  'fall043.jpg',
#  'fall044.jpg',
#  'fall045.jpg',
#  'fall046.jpg',
#  'fall047.jpg',
#  'fall048.jpg',
#  'fall049.jpg',
#  'fall050.jpg',
#  'fall051.jpg',
#  'fall052.jpg',
#  'fall053.jpg',
#  'fall054.jpg',
#  'fall055.jpg',
# ...
